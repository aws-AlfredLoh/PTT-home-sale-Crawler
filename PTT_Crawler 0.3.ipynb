# %%
import requests
import re
import urllib3
import json
from bs4 import BeautifulSoup

urllib3.disable_warnings()

# %%
allowed_domains='https://www.ptt.cc'

# %%
buy=[]
sell=[]

# %%
def get_web_page(url):
    if url:
        res=requests.get(url=url,verify=False)
        soup=BeautifulSoup(res.text,'lxml')
        return (soup,url)
    else:
        return None,None

# %%
def next_page(soup):
    if(soup.find('div',{'class':'btn-group btn-group-paging'}).find('a','btn wide disabled',string="‹ 上頁")):
        return None
    else:
        result=soup.find('div',{'class':'btn-group btn-group-paging'}).find("a",string="‹ 上頁").get('href')
        link=allowed_domains+result
        return link

# %%
def data_extraction_sell(string):
    i=1
    data={}
    
    if re.search(r"餐廳名稱：(.+)",string)!=None:
        data['餐廳名稱']=re.search(r"餐廳名稱：(.+)",string).group(i)    
    else:
        data['餐廳名稱']="record not found"
    
    if re.search(r"消費時間：(\d+(\.\d+))",string)!=None:
        data['消費時間']=re.search(r"消費時間：(\d+(\.\d+))",string).group(i)
    else:
        data['消費時間']="record not found"

    if re.search(r"房屋類型：(.+)",string)!=None:
        data['房屋類型']=re.search(r"房屋類型：(.+)",string).group(i)
    else:
        data['房屋類型']="record not found"

    if re.search(r"建物權狀：(\d+(\.\d+))",string)!=None:
        data['建物權狀']=re.search(r"建物權狀：(\d+(\.\d+))",string).group(i)
    else:
        data['建物權狀']="record not found"

    if re.search(r"附屬建物：(\d+(\.\d+))",string)!=None:
        data['附屬建物']=re.search(r"附屬建物：(\d+(\.\d+))",string).group(i)
    else:
        data['附屬建物']="record not found"

    if re.search(r"共同使用：(\d+(\.\d+))",string)!=None:
        data['共同使用']=re.search(r"共同使用：(\d+(\.\d+))",string).group(i)
    else:
        data['共同使用']="record not found"

    if re.search(r"車位：(\d+(\.\d+))",string)!=None:
        data['車位']=re.search(r"車位：(\d+(\.\d+))",string).group(i)
    else:
        data['車位']="record not found"

    if re.search(r"建物權狀是否包含車位坪數：(.+)",string)!=None:
        data['建物權狀是否包含車位坪數']=re.search(r"建物權狀是否包含車位坪數：(.+)",string).group(i)
    else:
        data['建物權狀是否包含車位坪數']="record not found"

    if re.search(r"土地權狀：(\d+(\.\d+))",string)!=None:
        data['土地權狀']=re.search(r"土地權狀：(\d+(\.\d+))",string).group(i)
    else:
        data['土地權狀']="record not found"

    if re.search(r"格局：(.+)",string)!=None:
        data['格局']=re.search(r"格局：(.+)",string).group(i)
    else:
        data['格局']="record not found"

    if re.search(r"開價：(\d+(\.\d+))",string)!=None:
        data['開價']=re.search(r"開價：(\d+(\.\d+))",string).group(i)
    else:
        data['開價']="record not found"

    return data

# %%
def data_extraction_buy(string):
    i=1
    data={}
    
    if re.search(r"房屋地點：(.+)",string)!=None:
        data['房屋地點']=re.search(r"房屋地點：(.+)",string).group(i)    
    else:
        data['房屋地點']="record not found"

    if re.search(r"房屋屋齡：(\d+(\.\d+))",string)!=None:
        data['房屋屋齡']=re.search(r"房屋屋齡：(\d+(\.\d+))",string).group(i)
    else:
        data['房屋屋齡']="record not found"

    if re.search(r"房屋類型：(.+)",string)!=None:
        data['房屋類型']=re.search(r"房屋類型：(.+)",string).group(i)
    else:
        data['房屋類型']="record not found"

    if re.search(r"房屋坪數：(\d+(\.\d+))",string)!=None:
        data['房屋坪數']=re.search(r"房屋坪數：(\d+(\.\d+))",string).group(i)
    else:
        data['房屋坪數']="record not found"

    if re.search(r"停車位：(\d+(\.\d+))",string)!=None:
        data['停車位']=re.search(r"停車位：(\d+(\.\d+))",string).group(i)
    else:
        data['停車位']="record not found"

    if re.search(r"車位種類：(.+)",string)!=None:
        data['車位種類']=re.search(r"車位種類：(.+)",string).group(i)
    else:
        data['車位種類']="record not found"

    if re.search(r"房屋格局：(.+)",string)!=None:
        data['房屋格局']=re.search(r"房屋格局：(.+)",string).group(i)
    else:
        data['房屋格局']="record not found"

    if re.search(r"是否加蓋：(.+)",string)!=None:
        data['是否加蓋']=re.search(r"是否加蓋：(.+)",string).group(i)
    else:
        data['是否加蓋']="record not found"

    if re.search(r"房屋座向：(.+)",string)!=None:
        data['房屋座向']=re.search(r"房屋座向：(.+)",string).group(i)
    else:
        data['房屋座向']="record not found"

    if re.search(r"買價：(\d+(\.\d+))",string)!=None:
        data['買價']=re.search(r"買價：(\d+(\.\d+))",string).group(i)
    else:
        data['買價']="record not found"

    if re.search(r"需求時間：(.+)",string)!=None:
        data['需求時間']=re.search(r"需求時間：(.+)",string).group(i)
    
    if re.search(r"聯絡方式：(.+)",string)!=None:
        data['聯絡方式']=re.search(r"聯絡方式：(.+)",string).group(i)
    else:
        data['聯絡方式']="record not found"
        
    if re.search(r"其他聯絡：(.+)",string)!=None:
        data['其他聯絡']=re.search(r"其他聯絡：(.+)",string).group(i)
    else:
        data['其他聯絡']="record not found"
        
    return data

# %%
def find_date(date):
    first=Date.find(' ')
    second=Date.find(' ',first+1)
    third=Date.find(' ',second+1)
    fourth=Date.find(' ',third+1)
    day=Date[:first]
    date=Date[first+1:third]
    time=Date[third+1:fourth]
    year=Date[fourth+1:]
    return day,date,time,year

# %%
def save_data_json(soup,title_name):
    
    global buy
    global sell
    global day,date,time,year,Date
             
    start_quote=title_name.find('/')
    end_quote=title_name.find('/', start_quote+1)
    county=title_name[start_quote+1:end_quote]
    
    try:
        Date=soup.select('.article-meta-value')[3].text
    except:
        pass
    else:
        day,date,time,year=find_date(Date)
        
    string=re.sub(r"[ \u3000\f\r\t\v]","",soup.text)

    if "買" in title_name:
        data=data_extraction_buy(string)
        buy.append([county,year+' '+date,time,data])
        
    elif "賣" in title_name:
        data=data_extraction_sell(string)
        sell.append([county,year+' '+date,time,data])

# %%
j=1       
def name_filter(soup):
    
    global j
    
    for entry in soup.select('.r-ent'):
        
        title_name=entry.select('.title')[0].text
        
        if '[' in title_name and ']'in title_name:
            start_quote = title_name.find('[')
            end_quote = title_name.find(']', start_quote+1)
            title_name = title_name[start_quote+1:end_quote]
            
            if (any(c in title_name for c in ["買","賣"])):
                print(j,'.',title_name)
                j=j+1
                link=allowed_domains+entry.find('a').get('href')
                content,url=get_web_page(link)
                save_data_json(content,title_name)

# %%
(soup,url)=get_web_page(url='https://www.ptt.cc/bbs/home-sale/index.html')

k=1

while True:
    if url:
        print('Page:',k,':',url,'\n')
        k=k+1
        name_filter(soup)
        link=next_page(soup)
        (soup,url)=get_web_page(link)
    else:
        break
# Out:
# Page: 1 : https://www.ptt.cc/bbs/home-sale/index.html
#
# 85 . 買//
# 86 . 賣/新竹/竹北
# 87 . 賣/北市/中正
# 88 . 賣/台中/南屯
# Page: 2 : https://www.ptt.cc/bbs/home-sale/index4681.html
#
# 89 . 賣/新竹/東區
# 90 . 賣/新竹/東區
# 91 . 賣/新竹/東區
# 92 . 賣/新竹/竹北
# 93 . 賣/新竹/北區
# 94 . 賣/桃園/桃園
# 95 . 賣/台南/永康
# 96 . 賣/新竹/東區
# 97 . 賣/台南/仁德區
# Page: 3 : https://www.ptt.cc/bbs/home-sale/index4680.html
#
# 98 . 賣/新竹/竹東
# 99 . 賣/新竹/竹北
# 100 . 買//
# 101 . 賣/桃園/平鎮
# 102 . 賣/高雄/苓雅
# 103 . 賣/新北市/板橋
# 104 . 賣/新竹/竹北
# 105 . 賣/台南/東區
# 106 . 賣/台南/南區
# 107 . 賣/新竹/東區
# Page: 4 : https://www.ptt.cc/bbs/home-sale/index4679.html
#
# 108 . 賣/台中/南屯
# 109 . 賣/台南/歸仁區
# 110 . 賣/桃園/平鎮
# 111 . 賣/高雄/美濃
# 112 . 賣/台南/南區
# 113 . 買/高雄/多區
# 114 . 賣/新竹/竹北
# 115 . 賣/新竹/竹北
# 116 . 買/新竹/竹北
# 117 . 賣/台南/北區
# Page: 5 : https://www.ptt.cc/bbs/home-sale/index4678.html
#
# 118 . 賣/台南/北區
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-71f6109723ff> in <module>
#       7         print('Page:',k,':',url,'\n')
#       8         k=k+1
# ----> 9         name_filter(soup)
#      10         link=next_page(soup)
#      11         (soup,url)=get_web_page(link)
#
# <ipython-input-10-be7eb4febc15> in name_filter(soup)
#      17                 j=j+1
#      18                 link=allowed_domains+entry.find('a').get('href')
# ---> 19                 content,url=get_web_page(link)
#      20                 save_data_json(content,title_name)
#
# <ipython-input-4-2751d1b48ec6> in get_web_page(url)
#       1 def get_web_page(url):
#       2     if url:
# ----> 3         res=requests.get(url=url,verify=False)
#       4         soup=BeautifulSoup(res.text,'lxml')
#       5         return (soup,url)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     342             ca_cert_dir=self.ca_cert_dir,
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#     346         if self.assert_fingerprint:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     342             or IS_SECURETRANSPORT):
#     343         if HAS_SNI and server_hostname is not None:
# --> 344             return context.wrap_socket(sock, server_hostname=server_hostname)
#     345
#     346         warnings.warn(
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     451         while True:
#     452             try:
# --> 453                 cnx.do_handshake()
#     454             except OpenSSL.SSL.WantReadError:
#     455                 if not util.wait_for_read(sock, sock.gettimeout()):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1904         :return: None.
#    1905         """
# -> 1906         result = _lib.SSL_do_handshake(self._ssl)
#    1907         self._raise_ssl_error(self._ssl, result)
#    1908
#
# KeyboardInterrupt:

# %%
for entry in sell:
    print(entry[0],entry[1],'\n\n',entry[3],'\n')
# Out:
# 新竹 2019 Jul 18
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓(擇一，得依實際情形自行填入其它項目)', '建物權狀': '65.16', '附屬建物': '9.891', '共同使用': '14.772', '車位': '8.109', '建物權狀是否包含車位坪數': 'Y(選是或否)', '土地權狀': '6.001', '格局': '4房2廳2衛1陽台(填整數)', '開價': 'record not found'}
#
# 北市 2019 Jul 18
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '27.89', '附屬建物': '4.47', '共同使用': '3.63', '車位': 'record not found', '建物權狀是否包含車位坪數': 'N', '土地權狀': '2.33', '格局': '3房2廳2衛1陽台', '開價': 'record not found'}
#
# 台中 2019 Jul 18
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓(擇一，得依實際情形自行填入其它項目)', '建物權狀': '56.61', '附屬建物': '4.61', '共同使用': '22.75', '車位': '8.33', '建物權狀是否包含車位坪數': 'Y(選是或否)', '土地權狀': '4.649', '格局': '3房2廳2衛2陽台(填整數)', '開價': 'record not found'}
#
# 新竹 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '54.087', '附屬建物': '3.727', '共同使用': '22.391', '車位': '9.387', '建物權狀是否包含車位坪數': 'Y', '土地權狀': '7.874', '格局': '4房2廳2衛2陽台', '開價': 'record not found'}
#
# 新竹 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '60.070', '附屬建物': '5.832', '共同使用': '16.885', '車位': '6.898', '建物權狀是否包含車位坪數': 'Y', '土地權狀': '6.8', '格局': '3房2廳2衛2陽台(填整數)', '開價': 'record not found'}
#
# 新竹 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '38.41', '附屬建物': '3.025', '共同使用': '13.25', '車位': '8.19', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': '4.6585', '格局': '3房2廳2衛', '開價': 'record not found'}
#
# 新竹 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '57.268', '附屬建物': '3.79', '共同使用': '13.104', '車位': '7.577', '建物權狀是否包含車位坪數': 'record not found', '土地權狀':
衛', '開價': 'record not found'}
#
# 新竹 2019 Jul 14
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '50.253', '附屬建物': '4.401', '共同使用': '13.739', '車位': '6.809', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': '5.896', '格局': '3房2廳2衛1陽台', '開價': 'record not found'}
#
# 台南 2019 Jul 13
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '電梯大樓', '建物權狀': '37.39', '附屬建物': '4.45', '共同使用': '7.58', '車位': 'record not found', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': '7.95', '格局': '3房、2廳、2衛', '開價': 'record not found'}
#
# 台北 2019 Jul 13
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '電梯', '建物權狀': '16.62', '附屬建物': '1.26', '共同使用': '5.55', '車位': 'record not found', '建物權狀是否包含車位坪數': 'N(選是或否)', '土地權狀': '3.91', '格局': '1房1廳1衛1陽台', '開價': 'record not found'}
#
# 台中 2019 Jul 13
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '34.3', '附屬建物': '2.5', '共同使用': '9.0', '車位': '6.0', '建物權狀是否包含車位坪數': 'Y', '土地權狀': '3.4', '格局': '2房2廳1衛1陽台', '開價': 'record not found'}
#
# 新竹 2019 Jul 13
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '33.2', '附屬建物': '1.98', '共同使用': '8.63', '車位': '8.19', '建物權狀是否包含車位坪數': 'Y', '土地權狀': '3.025', '格局': '2房2廳1衛', '開價': 'record not found'}
#
# 新竹 2019 Jul 14
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓(擇一，得依實際情形自行填入其它項目)', '建物權狀': '74.495', '附屬建物': '4.964', '共同使用': '16.57', '車位': '20.022', '建物權狀是否包含車位坪數': 'Y(選是或否)', '土地權狀': '10.503', '格局': '3房2廳2衛2陽台(填整數)', '開價': 'record not found'}
#
# 台北 2019 Jul 14
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '公寓(擇一，得依實際情形自行填入其它項目)', '建物權狀': '47.85', '附屬建物': '5.07', '共同使用': 'record not found', '車位': 'record not found', '建物權狀是否包含車位坪數': 'N(選是或否)', '土地權狀': '13.61', '格局': '4房2廳2衛2陽台(填整數)', '開價': 'record not found'}
#
# 新竹 2019 Jul 14
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '社區大樓', '建物權狀': '77.482', '附屬建物': '6.764', '共同使用': '16.913', '車位': '14.649', '建物權狀是否包含車位坪數': 'Y', '土地權狀': '11.851', '格局': '4房2廳2衛', '開價': 'record not found'}
#
# 新竹 2019 Jul 13
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓(擇一，得依實際情形自行填入其它項目)', '建物權狀': '57.744', '附屬建物': '3.07', '共同使用': '15.696', '車位': '11.684', '建物權狀是否包含車位坪數': 'Y(選是或否)', '土地權狀': '10.576', '格局': '3房2廳2衛2陽台(填整數)', '開價': 'record not found'}
#
# 新北市 2019 Jul 13
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '39.11', '附屬建物': '4.15', '共同使用': '13.59', '車位': '9.8', '建物權狀是否包含車位坪數': 'N', '土地權狀': 'record not found', '格局': '3房2廳2衛1陽台', '開價': 'record not found'}
#
# 新竹 2019 Jul 13
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '55.67', '附屬建物': '5.08', '共同使用': '11.52', '車位': '8.88', '建物權狀是否包含車位坪數': 'Y', '土地權狀': '10.09', '格局': '4房2廳2衛1陽台', '開價': 'record not found'}
#
# 新竹 2019 Jul 13
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '32.462', '附屬建物': '3.554', '共同使用': '9.693', '車位': 'record not found', '建物權狀是否包含車位坪數': 'Y', '土地權狀': '5.739', '格局': '3房2廳2衛2陽台', '開價': 'record not found'}
#
# 桃園 2019 Jul 13
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '電梯大樓', '建物權狀': '50.7', '附屬建物': '3.68', '共同使用': '13.82', '車位': 'record not found', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': '6.77', '格局': '3房2衛2廳', '開價': 'record not found'}
#
# 台南 2019 Jul 13
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '透天厝', '建物權狀': '62.8', '附屬建物': '5.66', '共同使用': '0.04', '車位': 'record not found', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': '29.33', '格局': '5房、2廳、5衛', '開價': 'record not found'}
#
# 新竹 2019 Jul 13
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '社區大樓', '建物權狀': '54.770', '附屬建物': '5.021', '共同使用': '13.948', '車位': '8.724', '建物權狀是否包含車位坪數': 'Y', '土地權狀': '5.671', '格局': '3房2廳2衛', '開價': 'record not found'}
#
# 高雄 2019 Jul 13
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '電梯大樓', '建物權狀': '43.873', '附屬建物': '2.468', '共同使用': '14.834', '車位': 'record not found', '建物權狀是否包含車位坪數': 'Y', '土地權狀': '4.497', '格局': '3房2廳2衛1陽台', '開價': 'record not found'}
#
# 新竹 2019 Jul 13
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '48.339', '附屬建物': '4.567', '共同使用': '12.327', '車位': '8.431', '建物權狀是否包含車位坪數': 'Y', '土地權狀': '9.447', '格局': '3房2廳2衛1陽台', '開價': 'record not found'}
#
# 新竹 2019 Jul 18
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓(擇一，得依實際情形自行填入其它項目)', '建物權狀': '65.16', '附屬建物': '9.891', '共同使用': '14.772', '車位': '8.109', '建物權狀是否包含車位坪數': 'Y(選是或否)', '土地權狀': '6.001', '格局': '4房2廳2衛1陽台(填整數)', '開價': 'record not found'}
#
# 北市 2019 Jul 18
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '27.89', '附屬建物': '4.47', '共同使用': '3.63', '車位': 'record not found', '建物權狀是否包含車位坪數': 'N', '土地權狀': '2.33', '格局': '3房2廳2衛1陽台', '開價': 'record not found'}
#
# 台中 2019 Jul 18
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓(擇一，得依實際情形自行填入其它項目)', '建物權狀': '56.61', '附屬建物': '4.61', '共同使用': '22.75', '車位': '8.33', '建物權狀是否包含車位坪數': 'Y(選是或否)', '土地權狀': '4.649', '格局': '3房2廳2衛2陽台(填整數)', '開價': 'record not found'}
#
# 新竹 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '54.087', '附屬建物': '3.727', '共同使用': '22.391', '車位': '9.387', '建物權狀是否包含車位坪數': 'Y', '土地權狀': '7.874', '格局': '4房2廳2衛2陽台', '開價': 'record not found'}
#
# 新竹 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '60.070', '附屬建物': '5.832', '共同使用': '16.885', '車位': '6.898', '建物權狀是否包含車位坪數': 'Y', '土地權狀': '6.8', '格局': '3房2廳2衛2陽台(填整數)', '開價': 'record not found'}
#
# 新竹 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '38.41', '附屬建物': '3.025', '共同使用': '13.25', '車位': '8.19', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': '4.6585', '格局': '3房2廳2衛', '開價': 'record not found'}
#
# 新竹 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '57.268', '附屬建物': '3.79', '共同使用': '13.104', '車位': '7.577', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': '9.35', '格局': '4房/2廳/2衛/2陽台', '開價': 'record not found'}
#
# 新竹 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '46.37', '附屬建物': '4.3', '共同使用': '14.06', '車位': '2.49', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': '4.874', '格局': '3房2廳2衛1陽台', '開價': 'record not found'}
#
# 桃園 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '42.77', '附屬建物': '3.5876', '共同使用': '9.8974', '車位': '5.86', '建物權狀是否包含車位坪數': 'Y(選是或否)', '土地權狀': 'record not found', '格局': '3房2廳2衛2陽台(填整數)', '開價': 'record not found'}
#
# 台南 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '公寓大樓', '建物權狀': 'record not found', '附屬建物': 'record not found', '共同使用': 'record not found', '車位': 'record not found', '建物權狀是否包含車位坪數': 'N,可向管理員承租汽車位,或購買車位,但大樓用戶基', '土地權狀': 'record not found', '格局': '3房2廳2衛1陽台(填整數)', '開價': 'record not found'}
#
# 新竹 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '33.6', '附屬建物': '2.25', '共同使用': '8.80', '車位': '8.19', '建物權狀是否包含車位坪數': 'Y', '土地權狀': '3.145', '格局': '2房2廳1衛', '開價': 'record not found'}
#
# 台南 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '透天厝', '建物權狀': '49.98', '附屬建物': '2.55', '共同使用': 'record not found', '車位': 'record not found', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': '20.66', '格局': '4房、2廳、4衛', '開價': 'record not found'}
#
# 新竹 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '公寓', '建物權狀': '26.94', '附屬建物': '1.93', '共同使用': '8.74', '車位': 'record not found', '建物權狀是否包含車位坪數': 'N', '土地權狀': 'record not found', '格局': '2房2廳1衛1陽台(填整數)', '開價': 'record not found'}
#
# 新竹 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓(擇一，得依實際情形自行填入其它項目)', '建物權狀': '57.24', '附屬建物': '3.07', '共同使用': '11.16', '車位': '11.68', '建物權狀是否包含車位坪數': 'Y(選是或否)', '土地權狀': '5.16', '格局': '3房2廳2衛2陽台(填整數)', '開價': 'record not found'}
#
# 桃園 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '26.61', '附屬建物': '3.59', '共同使用': '5.96', '車位': 'record not found', '建物權狀是否包含車位坪數': 'N', '土地權狀': '3.01', '格局': '2房1廳2衛1陽台', '開價': 'record not found'}
#
# 高雄 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '電梯華廈', '建物權狀': '49.94', '附屬建物': '1.56', '共同使用': 'record not found', '車位': '10.49', '建物權狀是否包含車位坪數': 'Y', '土地權狀': '10.49', '格局': '3房2廳3衛1陽台', '開價': 'record not found'}
#
# 新北市 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '32.08', '附屬建物': 'record not found', '共同使用': '10.91', '車位': '9.8', '建物權狀是否包含車位坪數': 'N', '土地權狀': 'record not found', '格局': '3房2廳1.5衛1陽台', '開價': 'record not found'}
#
# 新竹 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '52.682', '附屬建物': '2.145', '共同使用': '13.371', '車位': '10.848', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': '8.06', '格局': '3房2廳2衛', '開價': 'record not found'}
#
# 台南 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '爬樓梯公寓', '建物權狀': '39.56', '附屬建物': 'record not found', '共同使用': '2.4', '車位': 'record not found', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': '12.07', '格局': '4房、2廳、2衛、3陽台', '開價': 'record not found'}
#
# 台南 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '透天別墅', '建物權狀': '102.97', '附屬建物': '6.32', '共同使用': '0.01', '車位': 'record not found', '建物權狀是否包含車位坪數': 'YES', '土地權狀': '31.2', '格局': '6房2廳4衛5陽台', '開價': 'record not found'}
#
# 新竹 2019 Jul 17
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '53.19', '附屬建物': '3.16', '共同使用': '11.19', '車位': '2.97', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': '4.7', '格局': '4房2廳2衛1陽台', '開價': 'record not found'}
#
# 台中 2019 Jul 16
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓(擇一，得依實際情形自行填入其它項目)', '建物權狀': '32.31', '附屬建物': '1.74', '共同使用': '5.27', '車位': 'record not found', '建物權狀是否包含車位坪數': 'Y(選是或否)', '土地權狀': 'record not found', '格局': '3房2廳2衛2陽台(填整數)', '開價': 'record not found'}
#
# 台南 2019 Jul 16
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '透天厝', '建物權狀': '52.81', '附屬建物': '13.06', '共同使用': 'record not found', '車位': 'record not found', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': '26.16', '格局': '5房、2廳、3衛', '開價': 'record not found'}
#
# 桃園 2019 Jul 16
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '公寓(擇一，得依實際情形自行填入其它項目)', '建物權狀': '43.68', '附屬建物': '2.70', '共同使用': '14.62', '車位': 'record not found', '建物權狀是否包含車位坪數': 'Y(選是或否)', '土地權狀': '10.83', '格局': '3房2廳2衛2陽台(填整數)', '開價': 'record not found'}
#
# 高雄 2019 Jul 16
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': 'record not found', '建物權狀': 'record not found', '附屬建物': 'record not found', '共同使用': 'record not found', '車位': 'record not found', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': 'record not found', '格局': 'record not found', '開價': 'record not found'}
#
# 台南 2019 Jul 16
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': 'record not found', '建物權狀': 'record not found', '附屬建物': 'record not found', '共同使用': 'record not found', '車位': 'record not found', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': 'record not found', '格局': 'record not found', '開價': 'record not found'}
#
# 新竹 2019 Jul 16
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '大樓', '建物權狀': '59.992', '附屬建物': '4.129', '共同使用': '26.378', '車位': 'record not found', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': '8.058', '格局': '3房2廳2衛2陽台', '開價': 'record not found'}
#
# 新竹 2019 Jul 16
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '電梯大樓(擇一，得依實際情形自行填入其它項目)', '建物權狀': '72.86', '附屬建物': '3.07', '共同使用': '19.96', '車位': '11.74', '建物權狀是否包含車位坪數': '是(選是或否)', '土地權狀': '15.01', '格局': '4房2廳3衛2陽台(填整數)', '開價': 'record not found'}
#
# 台南 2019 Jul 16
#
#  {'餐廳名稱': 'record not found', '消費時間': 'record not found', '房屋類型': '邊間透天厝', '建物權狀': '23.82', '附屬建物': 'record not found', '共同使用': 'record not found', '車位': 'record not found', '建物權狀是否包含車位坪數': 'record not found', '土地權狀': '20.87', '格局': '5房、2廳、2衛', '開價': 'record not found'}

# %%
def file(data):
    with open("test",mode="w",encoding="utf-8")as file:
        json_string=json.dumps(data)
        file.write(json_string)

# %%
file(buy)
